# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

from nltk.tokenize import word_tokenize
print(word_tokenize("Testing NLTK tokenizer for internship project."))
# Out:
# ['Testing', 'NLTK', 'tokenizer', 'for', 'internship', 'project', '.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 262.6 kB/s eta 0:00:49
#      --------------------------------------- 0.1/12.8 MB 409.6 kB/s eta 0:00:32
#       -------------------------------------- 0.2/12.8 MB 952.6 kB/s eta 0:00:14
#      - -------------------------------------- 0.5/12.8 MB 2.2 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.3/12.8 MB 4.9 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.8 MB 7.8 MB/s eta 0:00:02
#      ------- -------------------------------- 2.4/12.8 MB 7.8 MB/s eta 0:00:02
#      --------- ------------------------------ 3.0/12.8 MB 7.3 MB/s eta 0:00:02
#      --------- ------------------------------ 3.0/12.8 MB 6.9 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.5/12.8 MB 6.9 MB/s eta 0:00:02
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Testing spaCy for the internship project.")
for token in doc:
    print(token.text, token.pos_)
# Out:
# Testing VERB
# spaCy NUM
# for ADP
# the DET
# internship NOUN
# project NOUN
# . PUNCT

# %%
from datasets import Dataset

# Local dummy data se dataset banate hain - library ka test hai, real download ki zaroorat nahi
data = {"text": ["Hello world", "Testing datasets library", "Internship project"], "label": [0, 1, 1]}
dataset = Dataset.from_dict(data)
print(dataset)
print(dataset[0])
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 3
# })
# {'text': 'Hello world', 'label': 0}

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
print(classifier("I am excited about this internship!"))
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  268MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9997674822807312}]
